# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
#reading dataset

# %%
data= pd.read_csv("dataset.csv")

# %%
data
# Out:
#                   Ticker        Date      Time    Open    High     Low  \
# 0       ACC28JAN211500PE  18/12/2020  10:41:59   22.00   22.00   22.00
# 1       ACC28JAN211540PE  18/12/2020  11:52:59   32.00   32.00   32.00
# 2       ACC28JAN211560PE  18/12/2020  10:42:59   40.00   40.00   40.00
# 3       ACC31DEC201400PE  18/12/2020  10:17:59    1.90    1.90    1.90
# 4       ACC31DEC201400PE  18/12/2020  10:55:59    1.90    1.90    1.90
# ...                  ...         ...       ...     ...     ...     ...
# 520931          ZEEL-III  18/12/2020  14:35:59  228.00  230.30  228.00
# 520932          ZEEL-III  18/12/2020  15:19:59  227.60  227.60  227.60
# 520933          ZEEL-III  18/12/2020  15:24:59  227.60  227.60  226.95
# 520934          ZEEL-III  18/12/2020  15:25:59  226.95  226.95  226.65
# 520935          ZEEL-III  18/12/2020  15:26:59  226.00  226.00  226.00
#
#          Close  Volume  Open Interest
# 0        22.00    1000           8000
# ...

# %%
#sorting data

# %%
data=data.sort_values("Ticker")

# %%
data
# Out:
#                   Ticker        Date      Time     Open     High      Low  \
# 2922               ACC-I  18/12/2020  13:39:59  1647.15  1648.95  1647.15
# 2683               ACC-I  18/12/2020  09:20:59  1639.35  1640.15  1639.15
# 2684               ACC-I  18/12/2020  09:21:59  1640.10  1642.00  1640.00
# 2685               ACC-I  18/12/2020  09:22:59  1639.95  1639.95  1636.95
# 2686               ACC-I  18/12/2020  09:23:59  1635.70  1637.45  1634.55
# ...                  ...         ...       ...      ...      ...      ...
# 520379  ZEEL31DEC20275CE  18/12/2020  10:00:59     0.85     0.85     0.85
# 520378  ZEEL31DEC20275CE  18/12/2020  09:47:59     1.00     1.00     1.00
# 520377  ZEEL31DEC20275CE  18/12/2020  09:22:59     1.15     1.15     1.15
# 520391  ZEEL31DEC20275CE  18/12/2020  11:40:59     1.00     1.00     1.00
# 520380  ZEEL31DEC20275CE  18/12/2020  10:02:59     0.65     0.65     0.65
#
#           Close  Volume  Open Interest
# 2922    1648.95    8500        3088000
# ...

# %%
#Finding particular option price on particular time

# %%
data1=data[data["Time"].between('12:04:59','12:09:59')]

# %%
data1
# Out:
#                   Ticker        Date      Time     Open     High      Low  \
# 2841               ACC-I  18/12/2020  12:04:59  1637.00  1638.55  1637.00
# 2842               ACC-I  18/12/2020  12:05:59  1638.55  1641.40  1638.55
# 2843               ACC-I  18/12/2020  12:06:59  1639.85  1640.30  1637.05
# 2844               ACC-I  18/12/2020  12:07:59  1637.05  1637.05  1636.35
# 2845               ACC-I  18/12/2020  12:08:59  1637.50  1638.05  1637.35
# ...                  ...         ...       ...      ...      ...      ...
# 519826  ZEEL31DEC20250CE  18/12/2020  12:04:59     3.65     3.65     3.65
# 519827  ZEEL31DEC20250CE  18/12/2020  12:05:59     3.65     3.65     3.60
# 519828  ZEEL31DEC20250CE  18/12/2020  12:06:59     3.60     3.65     3.60
# 519829  ZEEL31DEC20250CE  18/12/2020  12:07:59     3.65     3.65     3.65
# 519830  ZEEL31DEC20250CE  18/12/2020  12:09:59     3.65     3.65     3.65
#
#           Close  Volume  Open Interest
# 2841    1638.55    3500        3120000
# ...

# %%
#time for pe-12.04.59

# %%
data2=data[data["Ticker"].between('NIFTY31DEC2013700PE','NIFTY31DEC2013700PE')]

# %%
data2=data2[data["Time"].between('12:04:59','12:04:59')]
# Out:
# C:\Users\yaswa\AppData\Local\Temp/ipykernel_22904/286736504.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data2=data2[data["Time"].between('12:04:59','12:04:59')]

# %%
data2
# Out:
#                      Ticker        Date      Time    Open    High    Low  \
# 387311  NIFTY31DEC2013700PE  18/12/2020  12:04:59  146.85  146.85  145.7
#
#          Close  Volume  Open Interest
# 387311  146.25    3975         989925

# %%
#time for ce -12.09.59

# %%
data3=data[data["Ticker"].between('NIFTY31DEC2013700CE','NIFTY31DEC2013700CE')]

# %%
data3=data3[data["Time"].between('12:09:59','12:09:59')]
# Out:
# C:\Users\yaswa\AppData\Local\Temp/ipykernel_22904/1291341323.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data3=data3[data["Time"].between('12:09:59','12:09:59')]

# %%
data3
# Out:
#                      Ticker        Date      Time    Open   High    Low  \
# 386940  NIFTY31DEC2013700CE  18/12/2020  12:09:59  178.05  178.4  177.3
#
#         Close  Volume  Open Interest
# 386940  178.4    3300        1139475

# %%
#ticker-NIFTY31DEC2013700CE

# %%
tickerCE=data[data["Ticker"].between('NIFTY31DEC2013700CE','NIFTY31DEC2013700CE')]

# %%
tickerCE
# Out:
#                      Ticker        Date      Time    Open    High     Low  \
# 387016  NIFTY31DEC2013700CE  18/12/2020  13:25:59  175.40  175.40  172.95
# 387017  NIFTY31DEC2013700CE  18/12/2020  13:26:59  174.10  181.75  174.10
# 387018  NIFTY31DEC2013700CE  18/12/2020  13:27:59  180.45  187.75  180.05
# 387020  NIFTY31DEC2013700CE  18/12/2020  13:29:59  183.40  187.60  183.40
# 387022  NIFTY31DEC2013700CE  18/12/2020  13:31:59  187.70  190.00  186.60
# ...                     ...         ...       ...     ...     ...     ...
# 386887  NIFTY31DEC2013700CE  18/12/2020  11:16:59  173.95  174.55  172.90
# 386890  NIFTY31DEC2013700CE  18/12/2020  11:19:59  172.70  173.80  172.20
# 386891  NIFTY31DEC2013700CE  18/12/2020  11:20:59  173.50  174.00  173.25
# 386889  NIFTY31DEC2013700CE  18/12/2020  11:18:59  173.05  173.80  172.05
# 386884  NIFTY31DEC2013700CE  18/12/2020  11:13:59  172.60  173.90  172.00
#
#          Close  Volume  Open Interest
# 387016  174.10    6900        1194675
# ...

# %%
#ticker-NIFTY31DEC2013700PE

# %%
tickerPE=data[data["Ticker"].between('NIFTY31DEC2013700PE','NIFTY31DEC2013700PE')]

# %%
tickerPE
# Out:
#                      Ticker        Date      Time    Open    High     Low  \
# 387244  NIFTY31DEC2013700PE  18/12/2020  10:57:59  154.45  155.65  154.45
# 387243  NIFTY31DEC2013700PE  18/12/2020  10:56:59  154.20  155.20  153.85
# 387250  NIFTY31DEC2013700PE  18/12/2020  11:03:59  153.15  153.30  152.00
# 387245  NIFTY31DEC2013700PE  18/12/2020  10:58:59  154.70  155.60  153.95
# 387246  NIFTY31DEC2013700PE  18/12/2020  10:59:59  154.50  155.00  153.55
# ...                     ...         ...       ...     ...     ...     ...
# 387383  NIFTY31DEC2013700PE  18/12/2020  13:16:59  145.80  147.00  145.50
# 387373  NIFTY31DEC2013700PE  18/12/2020  13:06:59  148.65  148.70  147.30
# 387372  NIFTY31DEC2013700PE  18/12/2020  13:05:59  148.00  149.00  147.00
# 387371  NIFTY31DEC2013700PE  18/12/2020  13:04:59  146.45  149.00  146.45
# 387374  NIFTY31DEC2013700PE  18/12/2020  13:07:59  147.90  148.35  145.15
#
#          Close  Volume  Open Interest
# 387244  155.00    4800         931500
# ...

# %%
#18 dec 2020 13700 Pe time-12.05pm(open high low close)

# %%
data4=data[data["Ticker"].between('NIFTY31DEC2013700PE','NIFTY31DEC2013700PE')]

# %%
data4=data4[data["Time"].between('12:05:59','12:05:59')]
# Out:
# C:\Users\yaswa\AppData\Local\Temp/ipykernel_22904/2274505879.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data4=data4[data["Time"].between('12:05:59','12:05:59')]

# %%
data4=data4.drop(['Volume','Open Interest'],axis=1)

# %%
data4
# Out:
#                      Ticker        Date      Time    Open    High    Low  \
# 387312  NIFTY31DEC2013700PE  18/12/2020  12:05:59  146.25  146.25  145.5
#
#          Close
# 387312  145.55

# %%
data5=data[data["Ticker"].between('NIFTY31DEC2013700CE','NIFTY31DEC2013700CE')]

# %%
data5=data5[data["Time"].between('12:10:59','12:10:59')]
# Out:
# C:\Users\yaswa\AppData\Local\Temp/ipykernel_22904/4205347433.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data5=data5[data["Time"].between('12:10:59','12:10:59')]

# %%
data5=data5.drop(['Volume','Open Interest'],axis=1)

# %%
data
# Out:
#                   Ticker        Date      Time     Open     High      Low  \
# 2922               ACC-I  18/12/2020  13:39:59  1647.15  1648.95  1647.15
# 2683               ACC-I  18/12/2020  09:20:59  1639.35  1640.15  1639.15
# 2684               ACC-I  18/12/2020  09:21:59  1640.10  1642.00  1640.00
# 2685               ACC-I  18/12/2020  09:22:59  1639.95  1639.95  1636.95
# 2686               ACC-I  18/12/2020  09:23:59  1635.70  1637.45  1634.55
# ...                  ...         ...       ...      ...      ...      ...
# 520379  ZEEL31DEC20275CE  18/12/2020  10:00:59     0.85     0.85     0.85
# 520378  ZEEL31DEC20275CE  18/12/2020  09:47:59     1.00     1.00     1.00
# 520377  ZEEL31DEC20275CE  18/12/2020  09:22:59     1.15     1.15     1.15
# 520391  ZEEL31DEC20275CE  18/12/2020  11:40:59     1.00     1.00     1.00
# 520380  ZEEL31DEC20275CE  18/12/2020  10:02:59     0.65     0.65     0.65
#
#           Close  Volume  Open Interest
# 2922    1648.95    8500        3088000
# ...
